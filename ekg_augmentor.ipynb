# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
SEVERE_PATH = 'severe_ds.pt'
ds = torch.load(SEVERE_PATH)
ds
# Out:
# tensor([[[ -6061.8799, -10061.2998, -14000.0000,  ...,  -5997.5000,
#            -9963.7500, -13875.0000],
#          [ -6122.5000, -10122.5000, -14000.0000,  ...,  -6000.0000,
#            -9966.8799, -13878.7998],
#          [ -6184.3799, -10183.7998, -14000.0000,  ...,  -6003.1299,
#            -9970.6299, -13882.5000],
#          ...,
#          [ -6200.6299, -10152.5000, -13953.0996,  ...,  -6083.1299,
#           -10110.5996, -14021.2998],
#          [ -6205.0000, -10156.9004, -13952.5000,  ...,  -6083.1299,
#           -10110.5996, -14021.9004],
#          [ -6212.5000, -10163.7998, -13952.5000,  ...,  -6082.5000,
#           -10111.2998, -14023.7998]],
#
#         [[ -5998.7500,  -9996.2500, -13998.0996,  ...,  -5645.0000,
#            -9816.8799, -13756.9004],
#          [ -5998.1299,  -9994.3799, -13996.2998,  ...,  -5646.2500,
#            -9817.5000, -13758.0996],
#          [ -5998.1299,  -9993.7500, -13995.5996,  ...,  -5648.7500,
#            -9818.7500, -13760.0000],
# ...

# %%
ds[0].shape
# Out:
# torch.Size([2500, 12])
